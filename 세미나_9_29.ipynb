# %% [markdown]
# <a href="https://colab.research.google.com/github/hajeog/Seminar_class/blob/main/%EC%84%B8%EB%AF%B8%EB%82%98_9_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### <h1> 5장 딥러링과 텐서플로 </h1>
# > 1. 다층 퍼셉트론으로 MNIST인식하는 프로그램
# > 2. fashion MNIST 으로 인식하는 프로그램

# %% [markdown]
# #### 프로그램 5-7(b) 35p
# 다층퍼셉트론을 MLIST를 인식하는 프로그램 입니다.<br>
# 또한 hist 객체가 가진 정보를 이용하여 학습 곡선을 그립니다.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test) = mnist.load_data()

x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
x_train = x_train.astype(np.float32)/255.0
x_test = x_test.astype(np.float32)/255.0
y_train = tf.keras.utils.to_categorical(y_train,10)
y_test = tf.keras.utils.to_categorical(y_test,10)

n_input = 784
n_hidden = 1024
n_output = 10

mlp = Sequential()
mlp.add(Dense(units=n_hidden,activation='tanh',input_shape=(n_input,),kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_output,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist = mlp.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

res = mlp.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc = 'upper right')
plt.grid()
plt.show()
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/30
# 469/469 - 7s - loss: 0.0427 - accuracy: 0.8456 - val_loss: 0.0272 - val_accuracy: 0.9193 - 7s/epoch - 15ms/step
# Epoch 2/30
# 469/469 - 6s - loss: 0.0221 - accuracy: 0.9292 - val_loss: 0.0179 - val_accuracy: 0.9434 - 6s/epoch - 14ms/step
# Epoch 3/30
# 469/469 - 6s - loss: 0.0164 - accuracy: 0.9470 - val_loss: 0.0150 - val_accuracy: 0.9514 - 6s/epoch - 14ms/step
# Epoch 4/30
# 469/469 - 6s - loss: 0.0138 - accuracy: 0.9566 - val_loss: 0.0129 - val_accuracy: 0.9592 - 6s/epoch - 13ms/step
# Epoch 5/30
# 469/469 - 6s - loss: 0.0121 - accuracy: 0.9632 - val_loss: 0.0123 - val_accuracy: 0.9628 - 6s/epoch - 13ms/step
# Epoch 6/30
# 469/469 - 6s - loss: 0.0110 - accuracy: 0.9674 - val_loss: 0.0111 - val_accuracy: 0.9647 - 6s/epoch - 13ms/step
# Epoch 7/30
# 469/469 - 6s - loss: 0.0102 - accuracy: 0.9708 - val_loss: 0.0106 - val_accuracy: 0.9675 - 6s/epoch - 14ms/step
# Epoch 8/30
# ...

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![91630397-18838100-ea0c-11ea-8f90-515ef74599f1.png](data:image/png;base64,...)

# %% [markdown]
# ![adam.gif](data:image/gif;base64,...)

# %% [markdown]
# <h1>
# <a href = "https://arxiv.org/abs/1412.6980">[Adam 논문 코넬 대학교]</a>
# </h1>

# %% [markdown]
# ![세미나.png](data:image/png;base64,...)

# %% [markdown]
# #### 프로그램 5-8 38p
# fashion MNIST를 인식하여 학습하는 프로그램<br>
# <h9>이전 5-7(b) 프로그램과 거진 동일</h9>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import c

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()

x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
x_train = x_train.astype(np.float32)/255.0
x_test = x_test.astype(np.float32)/255.0
y_train = tf.keras.utils.to_categorical(y_train,10)
y_test = tf.keras.utils.to_categorical(y_test,10)

n_input = 784
n_hidden = 1024
n_output = 10

mlp = Sequential()
mlp.add(Dense(units=n_hidden,activation='tanh',input_shape=(n_input,),kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_output,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist = mlp.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

res = mlp.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc = 'upper right')
plt.grid()
plt.show()
# Out:
# Epoch 1/30
# 469/469 - 7s - loss: 0.0928 - accuracy: 0.4920 - val_loss: 0.0320 - val_accuracy: 0.8240 - 7s/epoch - 15ms/step
# Epoch 2/30
# 469/469 - 6s - loss: 0.0303 - accuracy: 0.8455 - val_loss: 0.0292 - val_accuracy: 0.8409 - 6s/epoch - 13ms/step
# Epoch 3/30
# 469/469 - 6s - loss: 0.0270 - accuracy: 0.8589 - val_loss: 0.0272 - val_accuracy: 0.8522 - 6s/epoch - 14ms/step
# Epoch 4/30
# 469/469 - 6s - loss: 0.0250 - accuracy: 0.8687 - val_loss: 0.0248 - val_accuracy: 0.8575 - 6s/epoch - 13ms/step
# Epoch 5/30
# 469/469 - 6s - loss: 0.0234 - accuracy: 0.8759 - val_loss: 0.0241 - val_accuracy: 0.8633 - 6s/epoch - 13ms/step
# Epoch 6/30
# 469/469 - 6s - loss: 0.0224 - accuracy: 0.8823 - val_loss: 0.0236 - val_accuracy: 0.8654 - 6s/epoch - 13ms/step
# Epoch 7/30
# 469/469 - 6s - loss: 0.0213 - accuracy: 0.8861 - val_loss: 0.0231 - val_accuracy: 0.8729 - 6s/epoch - 14ms/step
# Epoch 8/30
# ...

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![1-1.png](data:image/png;base64,...)

# %% [markdown]
# ![1-2.png](data:image/png;base64,...)

# %% [markdown]
# ![fashion_mnist-3.0.1.png](data:image/png;base64,...)

# %% [markdown]
# ![mnist_SVbcYYG.png](data:image/png;base64,...)

# %% [markdown]
# <a href="https://colab.research.google.com/github/hajeog/Seminar_class/blob/main/%EC%84%B8%EB%AF%B8%EB%82%98_10%EC%9B%94_6%EC%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 깊은 다층 퍼셉트론
# 1. MLIST 필기 숫자 data
# 2. fashion MNIST data

# %% [markdown]
# ## MLIST 필기숫자 data를 깊은 다층 퍼셉트론으로 인식
#
# - 다층 퍼셉트론을 구현 했던 [프로그램 5-7] 과 유사하다.
# - 은닉층이 1개 -> 4개로 증가함

# %%
from pickletools import optimize
from tabnanny import verbose
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
x_train = x_train.astype(np.float32)/255.0
x_test = x_test.astype(np.float32)/255.0
y_train = tf.keras.utils.to_categorical(y_train,10)
y_test = tf.keras.utils.to_categorical(y_test,10)

n_input = 784
n_hidden1 = 1024
n_hidden2=512
n_hidden3=512
n_hidden4=512
n_output = 10

mlp=Sequential()
mlp.add(Dense(units=n_hidden1,activation='tanh',input_shape=(n_input,),kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_hidden2,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_hidden3,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_hidden4,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_output,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=mlp.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

res = mlp.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper left')
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper right')
plt.grid()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/30
# 469/469 - 2s - loss: 0.0258 - accuracy: 0.8948 - val_loss: 0.0125 - val_accuracy: 0.9431 - 2s/epoch - 5ms/step
# Epoch 2/30
# 469/469 - 2s - loss: 0.0100 - accuracy: 0.9539 - val_loss: 0.0079 - val_accuracy: 0.9606 - 2s/epoch - 4ms/step
# Epoch 3/30
# 469/469 - 2s - loss: 0.0065 - accuracy: 0.9688 - val_loss: 0.0063 - val_accuracy: 0.9686 - 2s/epoch - 3ms/step
# Epoch 4/30
# 469/469 - 2s - loss: 0.0050 - accuracy: 0.9764 - val_loss: 0.0054 - val_accuracy: 0.9730 - 2s/epoch - 3ms/step
# Epoch 5/30
# 469/469 - 2s - loss: 0.0042 - accuracy: 0.9803 - val_loss: 0.0054 - val_accuracy: 0.9724 - 2s/epoch - 4ms/step
# Epoch 6/30
# 469/469 - 2s - loss: 0.0036 - accuracy: 0.9837 - val_loss: 0.0048 - val_accuracy: 0.9747 - 2s/epoch - 4ms/step
# Epoch 7/30
# 469/469 - 2s - loss: 0.0031 - accuracy: 0.9859 - val_loss: 0.0053 - val_accuracy: 0.9729 - 2s/epoch - 3ms/step
# Epoch 8/30
# 469/469 - 2s - loss: 0.0029 - accuracy: 0.9872 - val_loss: 0.0047 - val_accuracy: 0.9778 - 2s/epoch - 3ms/step
# Epoch 9/30
# 469/469 - 2s - loss: 0.0026 - accuracy: 0.9881 - val_loss: 0.0047 - val_accuracy: 0.9742 - 2s/epoch - 3ms/step
# Epoch 10/30
# 469/469 - 2s - loss: 0.0023 - accuracy: 0.9896 - val_loss: 0.0042 - val_accuracy: 0.9769 - 2s/epoch - 4ms/step
# Epoch 11/30
# 469/469 - 2s - loss: 0.0022 - accuracy: 0.9904 - val_loss: 0.0046 - val_accuracy: 0.9732 - 2s/epoch - 4ms/step
# Epoch 12/30
# 469/469 - 2s - loss: 0.0021 - accuracy: 0.9912 - val_loss: 0.0040 - val_accuracy: 0.9783 - 2s/epoch - 4ms/step
# Epoch 13/30
# 469/469 - 2s - loss: 0.0019 - accuracy: 0.9914 - val_loss: 0.0041 - val_accuracy: 0.9776 - 2s/epoch - 4ms/step
# Epoch 14/30
# 469/469 - 2s - loss: 0.0017 - accuracy: 0.9930 - val_loss: 0.0042 - val_accuracy: 0.9771 - 2s/epoch - 3ms/step
# Epoch 15/30
# 469/469 - 2s - loss: 0.0017 - accuracy: 0.9926 - val_loss: 0.0047 - val_accuracy: 0.9747 - 2s/epoch - 4ms/step
# Epoch 16/30
# 469/469 - 2s - loss: 0.0015 - accuracy: 0.9937 - val_loss: 0.0036 - val_accuracy: 0.9798 - 2s/epoch - 3ms/step
# Epoch 17/30
# 469/469 - 2s - loss: 0.0013 - accuracy: 0.9944 - val_loss: 0.0038 - val_accuracy: 0.9792 - 2s/epoch - 4ms/step
# Epoch 18/30
# 469/469 - 2s - loss: 0.0015 - accuracy: 0.9934 - val_loss: 0.0041 - val_accuracy: 0.9772 - 2s/epoch - 3ms/step
# Epoch 19/30
# 469/469 - 2s - loss: 0.0013 - accuracy: 0.9949 - val_loss: 0.0038 - val_accuracy: 0.9786 - 2s/epoch - 3ms/step
# Epoch 20/30
# 469/469 - 1s - loss: 0.0012 - accuracy: 0.9950 - val_loss: 0.0038 - val_accuracy: 0.9803 - 1s/epoch - 3ms/step
# Epoch 21/30
# 469/469 - 2s - loss: 0.0012 - accuracy: 0.9952 - val_loss: 0.0053 - val_accuracy: 0.9738 - 2s/epoch - 4ms/step
# Epoch 22/30
# 469/469 - 2s - loss: 0.0011 - accuracy: 0.9960 - val_loss: 0.0036 - val_accuracy: 0.9787 - 2s/epoch - 4ms/step
# Epoch 23/30
# 469/469 - 1s - loss: 0.0011 - accuracy: 0.9953 - val_loss: 0.0039 - val_accuracy: 0.9793 - 1s/epoch - 3ms/step
# Epoch 24/30
# 469/469 - 2s - loss: 0.0011 - accuracy: 0.9955 - val_loss: 0.0035 - val_accuracy: 0.9808 - 2s/epoch - 3ms/step
# Epoch 25/30
# 469/469 - 2s - loss: 9.2188e-04 - accuracy: 0.9967 - val_loss: 0.0041 - val_accuracy: 0.9774 - 2s/epoch - 4ms/step
# Epoch 26/30
# 469/469 - 2s - loss: 9.0455e-04 - accuracy: 0.9966 - val_loss: 0.0038 - val_accuracy: 0.9794 - 2s/epoch - 5ms/step
# Epoch 27/30
# 469/469 - 2s - loss: 8.8480e-04 - accuracy: 0.9968 - val_loss: 0.0034 - val_accuracy: 0.9803 - 2s/epoch - 4ms/step
# Epoch 28/30
# 469/469 - 2s - loss: 7.9086e-04 - accuracy: 0.9972 - val_loss: 0.0034 - val_accuracy: 0.9814 - 2s/epoch - 4ms/step
# Epoch 29/30
# 469/469 - 2s - loss: 9.4807e-04 - accuracy: 0.9966 - val_loss: 0.0034 - val_accuracy: 0.9812 - 2s/epoch - 4ms/step
# Epoch 30/30
# 469/469 - 2s - loss: 9.0455e-04 - accuracy: 0.9965 - val_loss: 0.0033 - val_accuracy: 0.9817 - 2s/epoch - 4ms/step
# 정확률은 98.17000031471252

# %% [markdown]
# ##### (이전 히든레이어가 1개일때 결과)

# %% [markdown]
# ![1_1.png](data:image/png;base64,...)

# %% [markdown]
# ![1_21.png](data:image/png;base64,...)

# %% [markdown]
# ## fashion MNIST 를 깊은 다층 퍼셉트론으로 인식 하기
#
# - 다층 퍼셉트론을 구현 했던 [프로그램 5-7(b)] 과 유사하다.
# - 은닉층이 1개 -> 4개로 증가함

# %%
from pickletools import optimize
from tabnanny import verbose
from sklearn.model_selection import train_test_split

import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
x_train = x_train.astype(np.float32)/255.0
x_test = x_test.astype(np.float32)/255.0
y_train = tf.keras.utils.to_categorical(y_train,10)
y_test = tf.keras.utils.to_categorical(y_test,10)

n_input = 784
n_hidden1 = 1024
n_hidden2=512
n_hidden3=512
n_hidden4=512
n_output = 10

mlp=Sequential()
mlp.add(Dense(units=n_hidden1,activation='tanh',input_shape=(n_input,),kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_hidden2,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_hidden3,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_hidden4,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_output,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=mlp.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

res = mlp.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper left')
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper right')
plt.grid()
plt.show()
# Out:
# Epoch 1/30
# 469/469 - 2s - loss: 0.0352 - accuracy: 0.8082 - val_loss: 0.0264 - val_accuracy: 0.8404 - 2s/epoch - 5ms/step
# Epoch 2/30
# 469/469 - 2s - loss: 0.0233 - accuracy: 0.8572 - val_loss: 0.0241 - val_accuracy: 0.8496 - 2s/epoch - 4ms/step
# Epoch 3/30
# 469/469 - 2s - loss: 0.0209 - accuracy: 0.8673 - val_loss: 0.0229 - val_accuracy: 0.8558 - 2s/epoch - 3ms/step
# Epoch 4/30
# 469/469 - 2s - loss: 0.0195 - accuracy: 0.8762 - val_loss: 0.0205 - val_accuracy: 0.8665 - 2s/epoch - 3ms/step
# Epoch 5/30
# 469/469 - 1s - loss: 0.0186 - accuracy: 0.8817 - val_loss: 0.0241 - val_accuracy: 0.8429 - 1s/epoch - 3ms/step
# Epoch 6/30
# 469/469 - 1s - loss: 0.0179 - accuracy: 0.8868 - val_loss: 0.0210 - val_accuracy: 0.8645 - 1s/epoch - 3ms/step
# Epoch 7/30
# 469/469 - 1s - loss: 0.0172 - accuracy: 0.8897 - val_loss: 0.0198 - val_accuracy: 0.8753 - 1s/epoch - 3ms/step
# Epoch 8/30
# 469/469 - 2s - loss: 0.0167 - accuracy: 0.8942 - val_loss: 0.0198 - val_accuracy: 0.8733 - 2s/epoch - 4ms/step
# Epoch 9/30
# 469/469 - 1s - loss: 0.0161 - accuracy: 0.8978 - val_loss: 0.0198 - val_accuracy: 0.8732 - 1s/epoch - 3ms/step
# Epoch 10/30
# 469/469 - 2s - loss: 0.0159 - accuracy: 0.8995 - val_loss: 0.0188 - val_accuracy: 0.8783 - 2s/epoch - 4ms/step
# Epoch 11/30
# 469/469 - 2s - loss: 0.0154 - accuracy: 0.9021 - val_loss: 0.0183 - val_accuracy: 0.8811 - 2s/epoch - 3ms/step
# Epoch 12/30
# 469/469 - 1s - loss: 0.0151 - accuracy: 0.9047 - val_loss: 0.0185 - val_accuracy: 0.8785 - 1s/epoch - 3ms/step
# Epoch 13/30
# 469/469 - 2s - loss: 0.0149 - accuracy: 0.9071 - val_loss: 0.0191 - val_accuracy: 0.8780 - 2s/epoch - 4ms/step
# Epoch 14/30
# 469/469 - 2s - loss: 0.0145 - accuracy: 0.9090 - val_loss: 0.0190 - val_accuracy: 0.8787 - 2s/epoch - 3ms/step
# Epoch 15/30
# 469/469 - 2s - loss: 0.0142 - accuracy: 0.9116 - val_loss: 0.0195 - val_accuracy: 0.8752 - 2s/epoch - 3ms/step
# Epoch 16/30
# 469/469 - 2s - loss: 0.0141 - accuracy: 0.9114 - val_loss: 0.0184 - val_accuracy: 0.8799 - 2s/epoch - 4ms/step
# Epoch 17/30
# 469/469 - 2s - loss: 0.0137 - accuracy: 0.9141 - val_loss: 0.0181 - val_accuracy: 0.8827 - 2s/epoch - 4ms/step
# Epoch 18/30
# 469/469 - 2s - loss: 0.0135 - accuracy: 0.9158 - val_loss: 0.0181 - val_accuracy: 0.8844 - 2s/epoch - 3ms/step
# Epoch 19/30
# 469/469 - 1s - loss: 0.0134 - accuracy: 0.9178 - val_loss: 0.0188 - val_accuracy: 0.8807 - 1s/epoch - 3ms/step
# Epoch 20/30
# 469/469 - 2s - loss: 0.0133 - accuracy: 0.9171 - val_loss: 0.0180 - val_accuracy: 0.8841 - 2s/epoch - 3ms/step
# Epoch 21/30
# 469/469 - 1s - loss: 0.0130 - accuracy: 0.9193 - val_loss: 0.0183 - val_accuracy: 0.8802 - 1s/epoch - 3ms/step
# Epoch 22/30
# 469/469 - 1s - loss: 0.0127 - accuracy: 0.9213 - val_loss: 0.0177 - val_accuracy: 0.8841 - 1s/epoch - 3ms/step
# Epoch 23/30
# 469/469 - 2s - loss: 0.0127 - accuracy: 0.9219 - val_loss: 0.0172 - val_accuracy: 0.8886 - 2s/epoch - 4ms/step
# Epoch 24/30
# 469/469 - 2s - loss: 0.0125 - accuracy: 0.9239 - val_loss: 0.0190 - val_accuracy: 0.8764 - 2s/epoch - 4ms/step
# Epoch 25/30
# 469/469 - 1s - loss: 0.0124 - accuracy: 0.9242 - val_loss: 0.0172 - val_accuracy: 0.8904 - 1s/epoch - 3ms/step
# Epoch 26/30
# 469/469 - 1s - loss: 0.0124 - accuracy: 0.9232 - val_loss: 0.0187 - val_accuracy: 0.8836 - 1s/epoch - 3ms/step
# Epoch 27/30
# 469/469 - 2s - loss: 0.0120 - accuracy: 0.9270 - val_loss: 0.0180 - val_accuracy: 0.8847 - 2s/epoch - 3ms/step
# Epoch 28/30
# 469/469 - 2s - loss: 0.0121 - accuracy: 0.9264 - val_loss: 0.0179 - val_accuracy: 0.8870 - 2s/epoch - 3ms/step
# Epoch 29/30
# 469/469 - 1s - loss: 0.0118 - accuracy: 0.9278 - val_loss: 0.0183 - val_accuracy: 0.8858 - 1s/epoch - 3ms/step
# Epoch 30/30
# 469/469 - 2s - loss: 0.0116 - accuracy: 0.9292 - val_loss: 0.0184 - val_accuracy: 0.8846 - 2s/epoch - 3ms/step
# 정확률은 88.45999836921692

# %% [markdown]
# ##### (이전 히든레이어가 1개일때 결과)

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# ## > Fashion MNIST

# %%
import tensorflow as tf

import matplotlib.pyplot as plt

# Load the fashion-mnist pre-shuffled train data and test data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# Define the text labels
fashion_mnist_labels = ["T-shirt/top",  # index 0
                        "Trouser",      # index 1
                        "Pullover",     # index 2 
                        "Dress",        # index 3 
                        "Coat",         # index 4
                        "Sandal",       # index 5
                        "Shirt",        # index 6 
                        "Sneaker",      # index 7 
                        "Bag",          # index 8 
                        "Ankle boot"]   # index 9

# Image index, you can pick any number between 0 and 59,999
img_index = 1
# y_train contains the lables, ranging from 0 to 9
label_index = y_train[img_index]
# Print the label, for example 2 Pullover
print ("y = " + str(label_index) + " " +(fashion_mnist_labels[label_index]))
# # Show one of the images from the training dataset
plt.imshow(x_train[img_index])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# y = 0 T-shirt/top

# %% [markdown]
# #[Fashion MNIST / CNN Beginner (98%)](https://www.kaggle.com/code/rutvikdeshpande/fashion-mnist-cnn-beginner-98/notebook)
